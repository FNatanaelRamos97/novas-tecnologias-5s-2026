# %% [markdown]
# # Exercício 1 - Cadastro e análise simples de veículos
#
# Uma concessionária deseja registrar alguns veículos disponíveis para venda.
# Crie um programa em Python que crie uma lista de veículos.
#
# Cada veículo deve ser representado por um dicionário contendo:
# - marca
# - modelo
# - preço
# - ano
#
# Exemplo de estrutura esperada:
#
# ```
# veiculo = {
#     "marca": "Toyota",
#     "modelo": "Corolla",
#     "preco": 120000,
#     "ano": 2022
# }
# ```
#
# O programa deve:
#
# - Adicionar pelo *menos 5 veículos* à lista.
# - Exibir todos os veículos cadastrados.
# - Calcular o *preço médio dos veículos*.
# - Mostrar quais *veículos custam acima da média*.
#
# ### Saída esperada (exemplo)
# ```
# Preço médio dos veículos: 85000
# Veículos acima da média:
# Honda Civic - 110000
# Toyota Corolla - 120000
# ```

# %%
veiculos = [
    {
        "Marca" :"Toyta",
        "Modelo":"Corolla",
        "Preco" : 120000,
        "Ano"   : 2022
    },
    {
        "Marca" :"Honda",
        "Modelo":"Civic",
        "Preco" : 130000,
        "Ano"   : 2023
    },
    {
        "Marca" :"Ford",
        "Modelo":"Focus",
        "Preco" : 90000,
        "Ano"   : 2019
    },
    {
        "Marca" :"Chevrolet",
        "Modelo":"Onix",
        "Preco" : 75000,
        "Ano"   : 2021
    },
    {
        "Marca" :"Hyundai",
        "Modelo":"HB20",
        "Preco" : 80000,
        "Ano"   : 2022
    }
]

# %%
soma = 0

for i, v in enumerate(veiculos, start=1):
    print("Veículo:", i)
    print("Marca  :", v["Marca"])
    print("Modelo :", v["Modelo"])
    print("Preço  :", v["Preco"])
    print("Ano    :", v["Ano"])
    print("**********************")
    soma += v["Preco"]

print("\nSoma total:",soma)
media = soma/len(veiculos)
print("\nA media de valor dos veiculos é de",media,"\n")

for v in veiculos:
    if v["Preco"] > media:
        print(v["Marca"], v["Modelo"], "está acima da média")
# Out:
# Veículo: 1
# Marca  : Toyta
# Modelo : Corolla
# Preço  : 120000
# Ano    : 2022
# **********************
# Veículo: 2
# Marca  : Honda
# Modelo : Civic
# Preço  : 130000
# Ano    : 2023
# **********************
# Veículo: 3
# Marca  : Ford
# Modelo : Focus
# Preço  : 90000
# Ano    : 2019
# **********************
# Veículo: 4
# Marca  : Chevrolet
# Modelo : Onix
# Preço  : 75000
# Ano    : 2021
# **********************
# Veículo: 5
# Marca  : Hyundai
# Modelo : HB20
# Preço  : 80000
# Ano    : 2022
# **********************
#
# Soma total: 495000
#
# A media de valor dos veiculos é de 99000.0
#
# Toyta Corolla está acima da média
# Honda Civic está acima da média

# %% [markdown]
# # Exercício 2 - Sistema simples de financiamento
#
# Uma concessionária oferece financiamento de veículos.
#
# Crie uma função chamada:
#
# ```
# calcular_financiamento(preco, entrada, parcelas)
# ```
#
# A função deve calcular o valor financiado.
#
# ```
# valor_financiado = preco - entrada
# ```
#
# Considerar uma taxa de juros simples de 1.5% ao mês.
#
# Fórmula simplificada:
# ```
# valor_total = valor_financiado * (1 + taxa * parcelas)
# parcela = valor_total / parcelas
# ```
# A função deve retornar o valor da parcela.
#
#
# ### Crie um programa que:
#
# - Defina o preço de um veículo
# - Pergunte ao usuário: valor de entrada e número de parcelas
# - Use a função para calcular o financiamento
# - Exiba o valor da parcela
# - Impedir parcelas maiores que 72 meses
# - Mostrar uma mensagem caso isso ocorra (Número máximo de parcelas é 72.)
#
# ### Exemplo de saída
#
# ```
# Preço do veículo: 80000
# Entrada: 20000
# Parcelas: 48
# Valor da parcela: 1785.50
# ```

# %%
def calcularParcelas(preco, entrada, parcelas):
    taxaJuros = 0.015
    valorFinanciado = preco - entrada
    valorTotal = valorFinanciado * (1 + taxaJuros * parcelas)
    return valorTotal / parcelas #retorna o valor da parcela

def linhas():
    for i in range(40):
        print("-",end="")
    print("\n")

valorVeiculo = float(input("Digite o valor do veiculo:"))
valorEntrada = float(input("Digite o valor de entrada:"))
numParcela   = int(input("Informe o numero de parcelas:"))

while numParcela > 72:
    print("Numero de parcelas superior ao limite permitido")
    numParcela   = int(input("Informe o numero de parcelas novamente:"))

linhas()
print(f"Preço do veiculo__________: {valorVeiculo}")
print(f"Valor da entrada__________: {valorEntrada}")
print(f"Numero de parcelas________: {numParcela}")
print(f"O valor da parcela fica em: {calcularParcelas(valorVeiculo, valorEntrada, numParcela)}")
linhas()
#print(f"Valor veiculo {valorVeiculo}")
# Out:
# Digite o valor do veiculo: 60000
# Digite o valor de entrada: 20000
# Informe o numero de parcelas: 80
# Numero de parcelas superior ao limite permitido
# Informe o numero de parcelas novamente: 75
# Numero de parcelas superior ao limite permitido
# Informe o numero de parcelas novamente: 55
# ----------------------------------------
#
# Preço do veiculo__________: 60000.0
# Valor da entrada__________: 20000.0
# Numero de parcelas________: 55
# O valor da parcela fica em: 1327.2727272727273
# ----------------------------------------
